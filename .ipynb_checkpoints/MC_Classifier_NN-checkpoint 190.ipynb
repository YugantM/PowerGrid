# %% [markdown]
# # Sequencial NN

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense,InputLayer,Dropout
from keras.layers import LSTM
from config.config import *
from config.constants import *
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from sklearn.metrics import accuracy_score,multilabel_confusion_matrix
from collections import Counter
from sklearn.model_selection import train_test_split

# %%
import os
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
def plot_model(hist):
    fig, axs = plt.subplots(nrows=1, figsize=(11, 9))
    plt.rcParams['font.size'] = '14'

    for label in (axs.get_xticklabels() + axs.get_yticklabels()):
        label.set_fontsize(14)    

    plt.plot(hist.history['accuracy'])
    plt.plot(hist.history['val_accuracy'])

    axs.set_title('Model Accuracy')
    axs.set_ylabel('Accuracy', fontsize=14)
    axs.set_xlabel('Epoch', fontsize=14)
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()
    
    print("Model has training accuracy of {:.2f}%".format(hist.history['accuracy'][-1]*100))

# %%
def pre_process_split(path):
    
    dataset = pd.read_csv(path)
    dataset.dropna(inplace = True)
    
    # assigning new column names to the dataframe
    # dataset.columns = constants.cols + ['label']
    
    # creating training set ignoring labels
    train_data = dataset[dataset.columns[:-1]].values
    #scaler = StandardScaler()    
    #train_data = scaler.fit_transform(train_data)

    labels = dataset['label'].values
    n_class = len(set(labels))
    
    X_train, X_test, y_train, y_test =   train_test_split(train_data, labels, test_size=0.20)

    X_train = X_train.reshape(-1, 1, train_data.shape[1])
    X_test  = X_test.reshape(-1, 1, train_data.shape[1])
    y_train = y_train.reshape(-1, 1, 1)
    y_test = y_test.reshape(-1, 1, 1)
    
    return X_train, X_test, y_train, y_test, n_class

# %%
def model_config_train(name,eps,bs,actvn,datalink):
    
    print("processing dataset")
    X_train, X_test, y_train, y_test, n_class = pre_process_split(datalink)
    
    print(n_class)
    model = Sequential()
    model.add(LSTM(200,input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dense(n_class, activation=actvn))
    print(model.summary())
       
    chk = ModelCheckpoint(name+'.pkl',save_best_only=True, mode='auto', verbose=1)
    print("saving as:",name+'.pkl')
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    hist = model.fit(X_train, y_train, epochs=eps, batch_size=bs, callbacks=[chk], validation_split=0.2)    
    plot_model(hist)
    
    return model

# %% [markdown]
# ## Loading dataset for binary classifier

# %%
def plotter(plot_data,unique_labels,n_plots):
    
    data = plot_data.copy()
    predicted_labels = data['label']
    #print(len(set(predicted_labels)),unique_labels)
    #print(Counter(predicted_labels).values(),[unique_labels[each] for each in Counter(predicted_labels).keys()])
    
    matrics = sorted(zip([unique_labels[each] for each in Counter(predicted_labels).keys()],Counter(predicted_labels).values() ), key=lambda x: x[1])
    cols = ['A'+str(each+1) for each in range(int(col_len/2))] + ['V'+str(each+1) for each in range(int(col_len/2))]
    score = [list(j) for j in matrics][::-1]
    
    
    
    total = sum([i[1] for i in score])

    c=0
    for i in score:

        score[c][1] = str(round(i[1]*100/total,2))+"%"
        #print("Fault type:", i[-1], "Percentage: {:.2f}%".format(i[1]*100/total))
        c+=1

    print(pd.DataFrame.from_records(score,columns=['Fault type','Percentage']))
    
    #print("changing numbers to labels again")
    data['label'] = [unique_labels[i] for i in predicted_labels]

    fig, ax = plt.subplots(n_plots,figsize=(15,4*n_plots))

    for j in range(n_plots):

        legend_list = []
        available_labels = [each[0] for each in score ]
        
        for i in range(len(available_labels)):

            extract = data[data.label==available_labels[i]][cols[j]]    

            if len(unique_labels)==2:
                
                if available_labels[i]=='FAULT':
                    temp = ax[j].scatter(extract.index,extract,marker='+',s=40) 
                elif available_labels[i]=='NML':
                    temp = ax[j].scatter(extract.index,extract,marker='.',s=10) 
            else:
                #print(available_labels[i],score[i][0],score[i][1])
                if available_labels[i]==score[0][0]:
                    temp = ax[j].scatter(extract.index,extract,marker='+',s=40)
                else:
                    temp = ax[j].scatter(extract.index,extract,marker='.',s=10)


            legend_list.append(temp)

        ax[j].legend(legend_list,available_labels,scatterpoints=3,ncol=1,fontsize=15)

    fig.tight_layout()
    plt.show()

    return score[0][0]

# %%
def tester(model,frame):
    
    data = frame
    
    cols = ['A'+str(each+1) for each in range(int(col_len/2))] + ['V'+str(each+1) for each in range(int(col_len/2))]
    
    if data.shape[1]==6:
        data.columns = cols
    elif data.shape[1]==7:
        data.columns = cols + ['label']
        data = data[cols]
    else:
        print("columns length is ",data.shape[1])
    
    test_preds = model.predict(data)
    #test_preds = model.predict(data.values.reshape(-1,1,6).tolist())
    predicted_labels = np.argmax(test_preds,axis=1)
    
    data['label'] = predicted_labels
    
    return data

# %% [markdown]
# ## Testing the models

# %%
model_config_train('binary_clf',6,2000,'softmax','./TrainingSet/binary/bin_dataset_simulink.csv')
# Out:
# processing dataset
# 2
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_13 (LSTM)               (None, 1, 100)            42800
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 100)            0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1, 100)            0
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1, 100)            0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1, 2)              202
# =================================================================
# Total params: 203,802
# Trainable params: 203,802
# Non-trainable params: 0
# _________________________________________________________________
# None
# saving as: binary_clf.pkl
# Epoch 1/20
# 704/704 [==============================] - 26s 32ms/step - loss: 0.3427 - accuracy: 0.8732 - val_loss: 0.1553 - val_accuracy: 0.9456
#
# Epoch 00001: val_loss improved from inf to 0.15527, saving model to binary_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses, lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# Epoch 2/20
# 704/704 [==============================] - 22s 31ms/step - loss: 0.1612 - accuracy: 0.9406 - val_loss: 0.1389 - val_accuracy: 0.9493
#
# Epoch 00002: val_loss improved from 0.15527 to 0.13885, saving model to binary_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses, lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# Epoch 3/20
# 704/704 [==============================] - 22s 31ms/step - loss: 0.1472 - accuracy: 0.9451 - val_loss: 0.1306 - val_accuracy: 0.9517
#
# Epoch 00003: val_loss improved from 0.13885 to 0.13057, saving model to binary_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses, lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# Epoch 4/20
# 704/704 [==============================] - 22s 31ms/step - loss: 0.1434 - accuracy: 0.9473 - val_loss: 0.1299 - val_accuracy: 0.9527
#
# Epoch 00004: val_loss improved from 0.13057 to 0.12988, saving model to binary_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses, lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# Epoch 5/20
# 704/704 [==============================] - 22s 31ms/step - loss: 0.1387 - accuracy: 0.9495 - val_loss: 0.1256 - val_accuracy: 0.9557
#
# Epoch 00005: val_loss improved from 0.12988 to 0.12557, saving model to binary_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses, lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# Epoch 6/20
# 704/704 [==============================] - 21s 30ms/step - loss: 0.1363 - accuracy: 0.9511 - val_loss: 0.1282 - val_accuracy: 0.9563
#
# Epoch 00006: val_loss did not improve from 0.12557
# Epoch 7/20
# 704/704 [==============================] - 22s 31ms/step - loss: 0.1350 - accuracy: 0.9522 - val_loss: 0.1243 - val_accuracy: 0.9557
#
# Epoch 00007: val_loss improved from 0.12557 to 0.12426, saving model to binary_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses, lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# Epoch 8/20
# 704/704 [==============================] - 21s 30ms/step - loss: 0.1338 - accuracy: 0.9522 - val_loss: 0.1226 - val_accuracy: 0.9546
#
# Epoch 00008: val_loss improved from 0.12426 to 0.12259, saving model to binary_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses, lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# Epoch 9/20
# 704/704 [==============================] - 22s 31ms/step - loss: 0.1300 - accuracy: 0.9535 - val_loss: 0.1225 - val_accuracy: 0.9568
#
# Epoch 00009: val_loss improved from 0.12259 to 0.12254, saving model to binary_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses, lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# Epoch 10/20
# 704/704 [==============================] - 21s 30ms/step - loss: 0.1300 - accuracy: 0.9538 - val_loss: 0.1209 - val_accuracy: 0.9552
#
# Epoch 00010: val_loss improved from 0.12254 to 0.12090, saving model to binary_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses, lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# Epoch 11/20
# 704/704 [==============================] - 22s 31ms/step - loss: 0.1318 - accuracy: 0.9536 - val_loss: 0.1242 - val_accuracy: 0.9582
#
# Epoch 00011: val_loss did not improve from 0.12090
# Epoch 12/20
# 704/704 [==============================] - 23s 32ms/step - loss: 0.1269 - accuracy: 0.9548 - val_loss: 0.1181 - val_accuracy: 0.9589
#
# Epoch 00012: val_loss improved from 0.12090 to 0.11807, saving model to binary_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses, lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# Epoch 13/20
# 303/704 [===========>..................] - ETA: 12s - loss: 0.1260 - accuracy: 0.9552
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-117-2d44f4dcb335> in <module>
# ----> 1 model_config_train('binary_clf',20,2000,'softmax','./TrainingSet/binary/bin_dataset_simulink.csv')
#
# <ipython-input-116-ddf8c096b7a9> in model_config_train(name, eps, bs, actvn, datalink)
#      18     print("saving as:",name+'.pkl')
#      19     model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# ---> 20     hist = model.fit(X_train, y_train, epochs=eps, batch_size=bs, callbacks=[chk], validation_split=0.2)
#      21     plot_model(hist)
#      22
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1156                 _r=1):
#    1157               callbacks.on_train_batch_begin(step)
# -> 1158               tmp_logs = self.train_function(iterator)
#    1159               if data_handler.should_sync:
#    1160                 context.async_wait()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3021       (graph_function,
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958         and executing_eagerly):
#    1959       # No tape is watching; skip to running the function.
# -> 1960       return self._build_call_outputs(self._inference_function.call(
#    1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model_config_train('multi_clf',5,2000,'softmax','./KMTrainingSet/multi/mul_dataset_simulink.csv')
# Out:
# processing dataset
# 11
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_16 (LSTM)               (None, 1, 100)            42800
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1, 100)            0
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1, 100)            0
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1, 100)            0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1, 11)             1111
# =================================================================
# Total params: 204,711
# Trainable params: 204,711
# Non-trainable params: 0
# _________________________________________________________________
# None
# saving as: multi_clf.pkl
# Epoch 1/5
# 92/92 [==============================] - 8s 47ms/step - loss: 1.9117 - accuracy: 0.4630 - val_loss: 0.3318 - val_accuracy: 0.8822
#
# Epoch 00001: val_loss improved from inf to 0.33176, saving model to multi_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_24_layer_call_fn, lstm_cell_24_layer_call_and_return_conditional_losses, lstm_cell_25_layer_call_fn, lstm_cell_25_layer_call_and_return_conditional_losses, lstm_cell_26_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# Epoch 2/5
# 92/92 [==============================] - 3s 37ms/step - loss: 0.2929 - accuracy: 0.8738 - val_loss: 0.2091 - val_accuracy: 0.8844
#
# Epoch 00002: val_loss improved from 0.33176 to 0.20905, saving model to multi_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_24_layer_call_fn, lstm_cell_24_layer_call_and_return_conditional_losses, lstm_cell_25_layer_call_fn, lstm_cell_25_layer_call_and_return_conditional_losses, lstm_cell_26_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# Epoch 3/5
# 92/92 [==============================] - 3s 36ms/step - loss: 0.2248 - accuracy: 0.8774 - val_loss: 0.2032 - val_accuracy: 0.8860
#
# Epoch 00003: val_loss improved from 0.20905 to 0.20316, saving model to multi_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_24_layer_call_fn, lstm_cell_24_layer_call_and_return_conditional_losses, lstm_cell_25_layer_call_fn, lstm_cell_25_layer_call_and_return_conditional_losses, lstm_cell_26_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# Epoch 4/5
# 92/92 [==============================] - 3s 37ms/step - loss: 0.2174 - accuracy: 0.8804 - val_loss: 0.2005 - val_accuracy: 0.8888
#
# Epoch 00004: val_loss improved from 0.20316 to 0.20051, saving model to multi_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_24_layer_call_fn, lstm_cell_24_layer_call_and_return_conditional_losses, lstm_cell_25_layer_call_fn, lstm_cell_25_layer_call_and_return_conditional_losses, lstm_cell_26_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# Epoch 5/5
# 92/92 [==============================] - 3s 38ms/step - loss: 0.2110 - accuracy: 0.8833 - val_loss: 0.1982 - val_accuracy: 0.8887
#
# Epoch 00005: val_loss improved from 0.20051 to 0.19820, saving model to multi_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_24_layer_call_fn, lstm_cell_24_layer_call_and_return_conditional_losses, lstm_cell_25_layer_call_fn, lstm_cell_25_layer_call_and_return_conditional_losses, lstm_cell_26_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# Model has training accuracy of 88.31%

# %%
binary_labels_list = ['NML','FAULT']
binary_model = load_model('binary_clf.pkl')

# %%
multi_labels_list = ['AB', 'AC', 'BC', 'ABC', 'AG', 'BG', 'ABG', 'CG', 'ACG', 'BCG', 'ABCG']
multi_model = load_model('multi_clf.pkl')

# %%
dat = pd.read_csv('./TrainingSet/1AB.csv')
data = tester(binary_model,dat)
plotter(data,binary_labels_list,2)
data = tester(multi_model,data[data.label!=0])
plotter(data,multi_labels_list,2)
# Out:
#   Fault type Percentage
# 0        NML     85.61%
# 1      FAULT     14.38%
#   Fault type Percentage
# 0         AB     36.84%
# 1         CG     36.64%
# 2        BCG     16.16%
# 3       ABCG       9.7%
# 4        ABG      0.66%
# 'AB'

# %%
# current directory
path = "./KMTrainingSet/"

# list of file of the given path is assigned to the variable 
file_list = [each for each in list(os.walk(path))[0][-1] if ".csv" in each]

# %%
files_failing_the_test = []
files_passing_the_test = []

for each in file_list:
    print("\n.\n.\n",each)  
    temp = tester(binary_model,pd.read_csv('./KMTrainingSet/'+each))
    plotter(temp,binary_labels_list,2)
    temp = tester(multi_model,temp[temp.label!=0])
    high = plotter(temp,multi_labels_list,2)
    if high == ''.join([i for i in each.split(".")[0] if not i.isdigit()]):
        files_passing_the_test.append(each)
    else:
        files_failing_the_test.append(each)
# Out:
# .
# .
#  5ABCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  10ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.97%
# 1        BCG      0.04%
# .
# .
#  3BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     80.15%
# 1        BCG     19.85%
# .
# .
#  3CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  1BCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     90.45%
# 1        BCG      9.54%
# .
# .
#  7BG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     98.61%
# 1        BCG       1.4%
# .
# .
#  5BG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     98.71%
# 1        BCG      1.29%
# .
# .
#  9ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.99%
# 1        BCG      0.01%
# .
# .
#  1BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.79%
# 1        BCG      0.21%
# .
# .
#  1CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  5ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  9AG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     87.33%
# 1        ABG     12.68%
# .
# .
#  7ABC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  7ACG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  7ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.97%
# 1        BCG      0.03%
# .
# .
#  9AC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.99%
# 1        BCG      0.01%
# .
# .
#  1BG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     98.59%
# 1        BCG      1.41%
# .
# .
#  5ABC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  5ACG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  9AB.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  9ACG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  9ABC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  5BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC      99.3%
# 1        BCG       0.7%
# .
# .
#  5CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  4ABCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  7BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     83.91%
# 1        BCG     16.09%
# .
# .
#  7CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  10ACG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  3BG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     98.72%
# 1        BCG      1.28%
# .
# .
#  10ABC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  3BCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.85%
# 1        BCG      0.15%
# .
# .
#  4BG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.45%
# 1        BCG      0.55%
# .
# .
#  1ABC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  1ACG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.95%
# 1        ABG      0.04%
# 2        BCG      0.01%
# .
# .
#  8AG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     67.25%
# 1        ABG     32.74%
# .
# .
#  3ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.99%
# 1        BCG      0.01%
# .
# .
#  10AC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  7BCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     85.75%
# 1        BCG     14.24%
# .
# .
#  6ABCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# 1        ABG      0.01%
# .
# .
#  6BG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.92%
# 1        BCG      0.09%
# .
# .
#  10AB.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  2BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     97.25%
# 1        BCG      2.75%
# .
# .
#  2CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  5BCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.75%
# 1        BCG      0.26%
# .
# .
#  2BG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     98.61%
# 1        BCG       1.4%
# .
# .
#  6BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     86.69%
# 1        BCG      13.3%
# .
# .
#  6CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  7ABCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  9BCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.81%
# 1        BCG      0.19%
# .
# .
#  10AG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     65.81%
# 1        ABG     34.19%
# .
# .
#  3ABC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# 1        ABG      0.01%
# .
# .
#  3ACG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  8AC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  4BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     74.75%
# 1        BCG     25.25%
# .
# .
#  4CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  1ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.98%
# 1        BCG      0.01%
# .
# .
#  8AB.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  10BCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        BCG      57.4%
# 1        ABC      42.6%
# .
# .
#  8CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  8BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     81.84%
# 1        BCG     18.16%
# .
# .
#  4AB.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  6ACG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# 1        BCG      0.01%
# .
# .
#  6ABC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# 1        BCG      0.01%
# .
# .
#  8ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.98%
# 1        BCG      0.02%
# .
# .
#  4AC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.99%
# 1        BCG      0.01%
# .
# .
#  4ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  2AG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC      98.7%
# 1        ABG       1.3%
# .
# .
#  6AC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.99%
# 1        BCG      0.01%
# .
# .
#  6AB.csv
#   Fault type Percentage
# 0      FAULT     100.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-937a790914d2> in <module>
#       5     print("\n.\n.\n",each)
#       6     temp = tester(binary_model,pd.read_csv('./KMTrainingSet/'+each))
# ----> 7     plotter(temp,binary_labels_list,2)
#       8     temp = tester(multi_model,temp[temp.label!=0])
#       9     high = plotter(temp,multi_labels_list,2)
#
# <ipython-input-6-45ebbc669c04> in plotter(plot_data, unique_labels, n_plots)
#      26     data['label'] = [unique_labels[i] for i in predicted_labels]
#      27
# ---> 28     fig, ax = plt.subplots(n_plots,figsize=(15,4*n_plots))
#      29
#      30     for j in range(n_plots):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1286     """
#    1287     fig = figure(**fig_kw)
# -> 1288     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1289                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1290                        gridspec_kw=gridspec_kw)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1520         if gridspec_kw is None:
#    1521             gridspec_kw = {}
# -> 1522         return (self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#    1523                 .subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#    1524                           subplot_kw=subplot_kw))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/gridspec.py in subplots(self, sharex, sharey, squeeze, subplot_kw)
#     334                 subplot_kw["sharex"] = shared_with[sharex]
#     335                 subplot_kw["sharey"] = shared_with[sharey]
# --> 336                 axarr[row, col] = figure.add_subplot(
#     337                     self[row, col], **subplot_kw)
#     338
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
# ---> 42         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      43         # add a layout box to this, for both the full axis, and the poss
#      44         # of the axis.  We need both because the axes may become smaller
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     509
#     510         self._rasterization_zorder = None
# --> 511         self.cla()
#     512
#     513         # funcs used to format x and y - fall back on major formatters
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in cla(self)
#    1159         self.set_axis_on()
#    1160
# -> 1161         self.xaxis.set_clip_path(self.patch)
#    1162         self.yaxis.set_clip_path(self.patch)
#    1163
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in set_clip_path(self, clippath, transform)
#     899     def set_clip_path(self, clippath, transform=None):
#     900         martist.Artist.set_clip_path(self, clippath, transform)
# --> 901         for child in self.majorTicks + self.minorTicks:
#     902             child.set_clip_path(clippath, transform)
#     903         self.stale = True
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     621             else:
#     622                 instance.minorTicks = []
# --> 623                 tick = instance._get_tick(major=False)
#     624                 instance.minorTicks.append(tick)
#     625                 return instance.minorTicks
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2011         else:
#    2012             tick_kw = self._minor_tick_kw
# -> 2013         return XTick(self.axes, 0, major=major, **tick_kw)
#    2014
#    2015     def set_label_position(self, position):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     433         # the y loc is 3 points below the min of y axis
#     434         trans, va, ha = self._get_text1_transform()
# --> 435         self.label1.set(
#     436             x=0, y=0,
#     437             verticalalignment=va, horizontalalignment=ha, transform=trans,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1111         if move_color_to_start:
#    1112             kwargs = {"color": kwargs.pop("color"), **kwargs}
# -> 1113         return self.update(kwargs)
#    1114
#    1115     def findobj(self, match=None, include_self=True):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/text.py in update(self, kwargs)
#     175         # Update bbox last, as it depends on font properties.
#     176         bbox = kwargs.pop("bbox", sentinel)
# --> 177         super().update(kwargs)
#     178         if bbox is not sentinel:
#     179             self.set_bbox(bbox)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#     996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
# --> 998                     ret.append(func(v))
#     999         if ret:
#    1000             self.pchanged()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/text.py in set_x(self, x)
#    1107         """
#    1108         self._x = x
# -> 1109         self.stale = True
#    1110
#    1111     def set_y(self, y):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in stale(self, val)
#     218         # draw stack and is not expected to be drawn as part of the normal
#     219         # draw loop (when not saving) so do not propagate this change
# --> 220         if self.get_animated():
#     221             return
#     222
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in get_animated(self)
#     796     def get_animated(self):
#     797         """Return whether the artist is animated."""
# --> 798         return self._animated
#     799
#     800     def get_in_layout(self):
#
# KeyboardInterrupt:

# %%
print(files_passing_the_test,"....\n\n....",files_failing_the_test)

# %%
names = [''.join([i for i in each.split(".")[0] if not i.isdigit()]) for each in files_passing_the_test]

# %%
Counter(names)

# %%
temp = tester(binary_model,pd.read_csv('ml_test.csv'))
plotter(temp,binary_labels_list,2)
temp = tester(multi_model,temp[temp.label!=0])
high = plotter(temp,multi_labels_list,2)
print(high)

# %%
files_failing_the_test = []
files_passing_the_test = []
for i in range(1,10):
    print("___________________________________________________________________")
    temp = tester(binary_model,pd.read_csv('./KMTrainingSet/'+str(i)+'ABC.csv'))
    plotter(temp,binary_labels_list,2)
    temp = tester(multi_model,temp[temp.label!=0])
    high = plotter(temp,multi_labels_list,2)
    if high == ''.join([i for i in each.split(".")[0] if not i.isdigit()]):
        checker.append(str(i)+'ABC.csv')
    else:
        checker.append('incorrect')
    print("----------------------------------------------------------------")

# %%
files_failing_model = [str(i)+'ABC.csv' for i in range(len(checker)) if checker[i]=='incorrect']

names = [''.join([i for i in each.split(".")[0] if not i.isdigit()]) for each in files_failing_model]

# %%
Counter(names)

# %%
data = pd.read_csv('./KMTrainingSet/1AG.csv')

# %%
round(data['3V'])

# %%
dat = Counter((round(data['3V'])/10))
matrics = sorted(zip([each for each in Counter(dat).keys()],Counter(dat).values() ), key=lambda x: x[0])

# %%
data = pd.read_csv('KMTrainingset/2ABG.csv')

# %%
features = data[data.columns[:-1]].values.tolist()
#true_labels = data['label'].values.tolist()

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
scaled_features

# %%
kmeans = KMeans(
    init="random",
    n_clusters=2,
    n_init=10,
    max_iter=500,
    random_state=42
)

# %%
kmeans.fit(scaled_features)

# %%
kmeans.cluster_centers_

# %%
labels = kmeans.fit_predict(features)

# %%
#data['label']=labels
data.head()

# %%
dic = Counter(labels)

# %%
dic

# %%
if dic[1]>dic[0]:
    print("1 = 0 , 0 =1")
    data['label']=[1 if i == 0 else 0 for i in labels]
else:
    print(True)

# %%
dic = Counter(data['label'])

# %%
data

# %%
n_plots = 6
fig, ax = plt.subplots(n_plots,figsize=(15,4*n_plots))
unique_labels = ['NML','Fault']
cols = data.columns[:-1]

for j in range(6):

    
    legend_list = []
    for i in list(set(data.label)):
        
        plo = data[data.label == i]
        temp = ax[j].scatter(plo.index,plo[cols[j]],marker='+',s=40)  


        legend_list.append(temp)

    ax[j].legend(legend_list,unique_labels,scatterpoints=3,ncol=1,fontsize=15)

fig.tight_layout()
plt.show()

# %%
org = [0,1,0,1,1,1,0,0,1,0,1]
[1 if i == 0 else 0 for i in org]

# %%
for x,y in zip(org,[1 if i == 0 else 0 for i in org]):
    print(x+y)
