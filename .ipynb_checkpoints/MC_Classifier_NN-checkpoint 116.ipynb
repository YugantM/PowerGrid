# %% [markdown]
# # Sequencial NN

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from config.config import *
from config.constants import *
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from sklearn.metrics import accuracy_score,multilabel_confusion_matrix
from collections import Counter
from sklearn.model_selection import train_test_split

# %%
import os
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
def plot_model(hist):
    fig, axs = plt.subplots(nrows=1, figsize=(11, 9))
    plt.rcParams['font.size'] = '14'

    for label in (axs.get_xticklabels() + axs.get_yticklabels()):
        label.set_fontsize(14)    

    plt.plot(hist.history['accuracy'])
    plt.plot(hist.history['val_accuracy'])

    axs.set_title('Model Accuracy')
    axs.set_ylabel('Accuracy', fontsize=14)
    axs.set_xlabel('Epoch', fontsize=14)
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()
    
    print("Model has training accuracy of {:.2f}%".format(hist.history['accuracy'][-1]*100))

# %%
def pre_process_split(path):
    
    dataset = pd.read_csv(path)
    dataset.dropna(inplace = True)
    
    # assigning new column names to the dataframe
    # dataset.columns = constants.cols + ['label']
    
    # creating training set ignoring labels
    train_data = dataset[dataset.columns[:-1]].values
    scaler = StandardScaler()    
    train_data = scaler.fit_transform(train_data)

    labels = dataset['label'].values
    n_class = len(set(labels))
    
    X_train, X_test, y_train, y_test =   train_test_split(train_data, labels, test_size=0.20)

    X_train = X_train.reshape(-1, 1, train_data.shape[1])
    X_test  = X_test.reshape(-1, 1, train_data.shape[1])
    y_train = y_train.reshape(-1, 1, 1)
    y_test = y_test.reshape(-1, 1, 1)
    
    return X_train, X_test, y_train, y_test, n_class

# %%
box_plot = None
def model_config_train(name,eps,bs,actvn,datalink):
    global box_plot
    print("processing dataset")
    X_train, X_test, y_train, y_test, n_class = pre_process_split(datalink)
    
    print(n_class)
    model = Sequential()
    model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dense(100,activation='relu'))
    model.add(Dense(n_class, activation=actvn))
    print(model.summary())
       
    chk = ModelCheckpoint(name+'.pkl',save_best_only=True, mode='auto', verbose=1)
    print("saving as:",name+'.pkl')
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    hist = model.fit(X_train, y_train, epochs=eps, batch_size=bs, callbacks=[chk], validation_split=0.2)    
    plot_model(hist)
    
    return model

# %% [markdown]
# ## Loading dataset for binary classifier

# %%
def plotter(plot_data,unique_labels,n_plots):
    
    data = plot_data.copy()
    predicted_labels = data['label']
    #print(len(set(predicted_labels)),unique_labels)
    #print(Counter(predicted_labels).values(),[unique_labels[each] for each in Counter(predicted_labels).keys()])
    
    matrics = sorted(zip([unique_labels[each] for each in Counter(predicted_labels).keys()],Counter(predicted_labels).values() ), key=lambda x: x[1])
    cols = ['A'+str(each+1) for each in range(int(col_len/2))] + ['V'+str(each+1) for each in range(int(col_len/2))]
    score = [list(j) for j in matrics][::-1]
    
    
    
    total = sum([i[1] for i in score])

    c=0
    for i in score:

        score[c][1] = str(round(i[1]*100/total,2))+"%"
        #print("Fault type:", i[-1], "Percentage: {:.2f}%".format(i[1]*100/total))
        c+=1

    print(pd.DataFrame.from_records(score,columns=['Fault type','Percentage']))
    
    #print("changing numbers to labels again")
    data['label'] = [unique_labels[i] for i in predicted_labels]

    fig, ax = plt.subplots(n_plots,figsize=(15,4*n_plots))

    for j in range(n_plots):

        legend_list = []
        for i in range(len(set(predicted_labels))):

            extract = data[data.label==unique_labels[i]][cols[j]]    

            #print(len(extract))
            if unique_labels[i]==score[0][0] and score[0][0]!='NML' or unique_labels[i]== 'FAULT':
                temp = ax[j].scatter(extract.index,extract,marker='+',s=40)
            else:
                temp = ax[j].scatter(extract.index,extract,marker='.',s=10)


            legend_list.append(temp)

        ax[j].legend(legend_list,unique_labels,scatterpoints=3,ncol=1,fontsize=15)

    fig.tight_layout()
    plt.show()

    return score[0][0]

# %%
def tester(model,frame):
    
    data = frame
    
    cols = ['A'+str(each+1) for each in range(int(col_len/2))] + ['V'+str(each+1) for each in range(int(col_len/2))]
    
    if data.shape[1]==6:
        data.columns = cols
    elif data.shape[1]==7:
        data.columns = cols + ['label']
        data = data[cols]
    else:
        print("columns length is ",data.shape[1])
    
    
    test_preds = model.predict(data.values.reshape(-1,1,6).tolist())
    predicted_labels = np.argmax(test_preds,axis=1)
    
    data['label'] = predicted_labels
    
    return data

# %% [markdown]
# ## Testing the models

# %%
model_config_train('binary_clf',20,2000,'softmax','./TrainingSet/binary/bin_dataset_simulink.csv')
# Out:
# processing dataset
# 2
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 100)               42800
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 53,102
# Trainable params: 53,102
# Non-trainable params: 0
# _________________________________________________________________
# None
# saving as: binary_clf.pkl
# Epoch 1/20
# 704/704 [==============================] - 9s 10ms/step - loss: 0.2985 - accuracy: 0.9051 - val_loss: 0.1587 - val_accuracy: 0.9512
#
# Epoch 00001: val_loss improved from inf to 0.15873, saving model to binary_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses, lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses, lstm_cell_9_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# Epoch 2/20
# 704/704 [==============================] - 8s 11ms/step - loss: 0.1513 - accuracy: 0.9536 - val_loss: 0.1339 - val_accuracy: 0.9553
#
# Epoch 00002: val_loss improved from 0.15873 to 0.13392, saving model to binary_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses, lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses, lstm_cell_9_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# INFO:tensorflow:Assets written to: binary_clf.pkl/assets
# Epoch 3/20
# 704/704 [==============================] - 8s 11ms/step - loss: 0.1280 - accuracy: 0.9556 - val_loss: 0.1150 - val_accuracy: 0.9588
#
# Epoch 00003: val_loss improved from 0.13392 to 0.11503, saving model to binary_clf.pkl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-2d44f4dcb335> in <module>
# ----> 1 model_config_train('binary_clf',20,2000,'softmax','./TrainingSet/binary/bin_dataset_simulink.csv')
#
# <ipython-input-17-cdd530c9a842> in model_config_train(name, eps, bs, actvn, datalink)
#      15     print("saving as:",name+'.pkl')
#      16     model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# ---> 17     hist = model.fit(X_train, y_train, epochs=eps, batch_size=bs, callbacks=[chk], validation_split=0.2)
#      18     plot_model(hist)
#      19
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1202           epoch_logs.update(val_logs)
#    1203
# -> 1204         callbacks.on_epoch_end(epoch, epoch_logs)
#    1205         training_logs = epoch_logs
#    1206         if self.stop_training:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     408     for callback in self.callbacks:
#     409       if getattr(callback, '_supports_tf_logs', False):
# --> 410         callback.on_epoch_end(epoch, logs)
#     411       else:
#     412         if numpy_logs is None:  # Only convert once.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#    1374     # pylint: disable=protected-access
#    1375     if self.save_freq == 'epoch':
# -> 1376       self._save_model(epoch=epoch, logs=logs)
#    1377
#    1378   def _should_save_on_batch(self, batch):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/callbacks.py in _save_model(self, epoch, logs)
#    1426                     filepath, overwrite=True, options=self._options)
#    1427               else:
# -> 1428                 self.model.save(filepath, overwrite=True, options=self._options)
#    1429             else:
#    1430               if self.verbose > 0:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2084     """
#    2085     # pylint: enable=line-too-long
# -> 2086     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
#    2087                     signatures, options, save_traces)
#    2088
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     148   else:
#     149     with generic_utils.SharedObjectSavingScope():
# --> 150       saved_model_save.save(model, filepath, overwrite, include_optimizer,
#     151                             signatures, options, save_traces)
#     152
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/save.py in save(model, filepath, overwrite, include_optimizer, signatures, options, save_traces)
#      88   with K.deprecated_internal_learning_phase_scope(0):
#      89     with utils.keras_option_scope(save_traces):
# ---> 90       saved_nodes, node_paths = save_lib.save_and_return_nodes(
#      91           model, filepath, signatures, options)
#      92
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/saved_model/save.py in save_and_return_nodes(obj, export_dir, signatures, options, raise_metadata_warning, experimental_skip_checkpoint)
#    1101
#    1102   _, exported_graph, object_saver, asset_info, saved_nodes, node_paths = (
# -> 1103       _build_meta_graph(obj, signatures, options, meta_graph_def,
#    1104                         raise_metadata_warning))
#    1105   saved_model.saved_model_schema_version = constants.SAVED_MODEL_SCHEMA_VERSION
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/saved_model/save.py in _build_meta_graph(obj, signatures, options, meta_graph_def, raise_metadata_warning)
#    1288
#    1289   with save_context.save_context(options):
# -> 1290     return _build_meta_graph_impl(obj, signatures, options, meta_graph_def,
#    1291                                   raise_metadata_warning)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/saved_model/save.py in _build_meta_graph_impl(obj, signatures, options, meta_graph_def, raise_metadata_warning)
#    1205   checkpoint_graph_view = _AugmentedGraphView(obj)
#    1206   if signatures is None:
# -> 1207     signatures = signature_serialization.find_function_to_export(
#    1208         checkpoint_graph_view)
#    1209
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/saved_model/signature_serialization.py in find_function_to_export(saveable_view)
#      97   # If the user did not specify signatures, check the root object for a function
#      98   # that can be made into a signature.
# ---> 99   functions = saveable_view.list_functions(saveable_view.root)
#     100   signature = functions.get(DEFAULT_SIGNATURE_ATTR, None)
#     101   if signature is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/saved_model/save.py in list_functions(self, obj)
#     152     obj_functions = self._functions.get(obj, None)
#     153     if obj_functions is None:
# --> 154       obj_functions = obj._list_functions_for_serialization(  # pylint: disable=protected-access
#     155           self._serialization_cache)
#     156       self._functions[obj] = obj_functions
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in _list_functions_for_serialization(self, serialization_cache)
#    2686     self.test_function = None
#    2687     self.predict_function = None
# -> 2688     functions = super(
#    2689         Model, self)._list_functions_for_serialization(serialization_cache)
#    2690     self.train_function = train_function
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/base_layer.py in _list_functions_for_serialization(self, serialization_cache)
#    2990
#    2991   def _list_functions_for_serialization(self, serialization_cache):
# -> 2992     return (self._trackable_saved_model_saver
#    2993             .list_functions_for_serialization(serialization_cache))
#    2994
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/base_serialization.py in list_functions_for_serialization(self, serialization_cache)
#      91       return {}
#      92
# ---> 93     fns = self.functions_to_serialize(serialization_cache)
#      94
#      95     # The parent AutoTrackable class saves all user-defined tf.functions, and
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/layer_serialization.py in functions_to_serialize(self, serialization_cache)
#      71
#      72   def functions_to_serialize(self, serialization_cache):
# ---> 73     return (self._get_serialized_attributes(
#      74         serialization_cache).functions_to_serialize)
#      75
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/layer_serialization.py in _get_serialized_attributes(self, serialization_cache)
#      87       return serialized_attr
#      88
# ---> 89     object_dict, function_dict = self._get_serialized_attributes_internal(
#      90         serialization_cache)
#      91
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/model_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#      51     # the ones serialized by Layer.
#      52     objects, functions = (
# ---> 53         super(ModelSavedModelSaver, self)._get_serialized_attributes_internal(
#      54             serialization_cache))
#      55     functions['_default_save_signature'] = default_signature
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/layer_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#      97     """Returns dictionary of serialized attributes."""
#      98     objects = save_impl.wrap_layer_objects(self.obj, serialization_cache)
# ---> 99     functions = save_impl.wrap_layer_functions(self.obj, serialization_cache)
#     100     # Attribute validator requires that the default save signature is added to
#     101     # function dict, even if the value is None.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/save_impl.py in wrap_layer_functions(layer, serialization_cache)
#     147   # Reset the losses of the layer and its children. The call function in each
#     148   # child layer is replaced with tf.functions.
# --> 149   original_fns = _replace_child_layer_functions(layer, serialization_cache)
#     150   original_losses = _reset_layer_losses(layer)
#     151
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/save_impl.py in _replace_child_layer_functions(layer, serialization_cache)
#     277     if child_layer not in serialization_cache[constants.KERAS_CACHE_KEY]:
#     278       serialized_functions = (
# --> 279           child_layer._trackable_saved_model_saver._get_serialized_attributes(
#     280               serialization_cache).functions)
#     281     else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/layer_serialization.py in _get_serialized_attributes(self, serialization_cache)
#      87       return serialized_attr
#      88
# ---> 89     object_dict, function_dict = self._get_serialized_attributes_internal(
#      90         serialization_cache)
#      91
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/layer_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#     149   def _get_serialized_attributes_internal(self, serialization_cache):
#     150     objects, functions = (
# --> 151         super(RNNSavedModelSaver, self)._get_serialized_attributes_internal(
#     152             serialization_cache))
#     153     states = tf.__internal__.tracking.wrap(self.obj.states)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/layer_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#      97     """Returns dictionary of serialized attributes."""
#      98     objects = save_impl.wrap_layer_objects(self.obj, serialization_cache)
# ---> 99     functions = save_impl.wrap_layer_functions(self.obj, serialization_cache)
#     100     # Attribute validator requires that the default save signature is added to
#     101     # function dict, even if the value is None.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/save_impl.py in wrap_layer_functions(layer, serialization_cache)
#     197           if isinstance(fn, LayerCall):
#     198             fn = fn.wrapped_call
# --> 199           fn.get_concrete_function()
#     200
#     201   # Restore overwritten functions and losses
#
# ~/opt/anaconda3/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/save_impl.py in tracing_scope()
#     360       if training is not None:
#     361         with K.deprecated_internal_learning_phase_scope(training):
# --> 362           fn.get_concrete_function(*args, **kwargs)
#     363       else:
#     364         fn.get_concrete_function(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in get_concrete_function(self, *args, **kwargs)
#    1365       ValueError: if this object has not yet been called on concrete values.
#    1366     """
# -> 1367     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1368     concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1369     return concrete
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1282       # In this case we have not created variables on the first call. So we can
#    1283       # run the first trace but we should fail if variables are created.
# -> 1284       concrete = self._stateful_fn._get_concrete_function_garbage_collected(  # pylint: disable=protected-access
#    1285           *args, **kwargs)
#    1286       if self._created_variables:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3098       args, kwargs = None, None
#    3099     with self._lock:
# -> 3100       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3101       seen_names = set()
#    3102       captured = object_identity.ObjectIdentitySet(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3442
#    3443           self._function_cache.missed.add(call_context_key)
# -> 3444           graph_function = self._create_graph_function(args, kwargs)
#    3445           self._function_cache.primary[cache_key] = graph_function
#    3446
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3277     arg_names = base_arg_names + missing_arg_names
#    3278     graph_function = ConcreteFunction(
# -> 3279         func_graph_module.func_graph_from_py_func(
#    3280             self._name,
#    3281             self._python_function,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     997         _, original_func = tf_decorator.unwrap(python_func)
#     998
# --> 999       func_outputs = python_func(*func_args, **func_kwargs)
#    1000
#    1001       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/save_impl.py in wrapper(*args, **kwargs)
#     592       with autocast_variable.enable_auto_cast_variables(
#     593           layer._compute_dtype_object):  # pylint: disable=protected-access
# --> 594         ret = method(*args, **kwargs)
#     595     _restore_layer_losses(original_losses)
#     596     return ret
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/utils.py in wrap_with_training_arg(*args, **kwargs)
#     162       return wrapped_call(*args, **kwargs)
#     163
# --> 164     return control_flow_util.smart_cond(
#     165         training, lambda: replace_training_and_call(True),
#     166         lambda: replace_training_and_call(False))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/utils/control_flow_util.py in smart_cond(pred, true_fn, false_fn, name)
#     104     return tf.compat.v1.cond(
#     105         pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 106   return smart_module.smart_cond(
#     107       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#     108
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      54       return true_fn()
#      55     else:
# ---> 56       return false_fn()
#      57   else:
#      58     return control_flow_ops.cond(pred, true_fn=true_fn, false_fn=false_fn,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/utils.py in <lambda>()
#     164     return control_flow_util.smart_cond(
#     165         training, lambda: replace_training_and_call(True),
# --> 166         lambda: replace_training_and_call(False))
#     167
#     168   # Create arg spec for decorated function. If 'training' is not defined in the
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/utils.py in replace_training_and_call(training)
#     160     def replace_training_and_call(training):
#     161       set_training_arg(training, training_arg_index, args, kwargs)
# --> 162       return wrapped_call(*args, **kwargs)
#     163
#     164     return control_flow_util.smart_cond(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/save_impl.py in call_and_return_conditional_losses(*args, **kwargs)
#     656   def call_and_return_conditional_losses(*args, **kwargs):
#     657     """Returns layer (call_output, conditional losses) tuple."""
# --> 658     call_output = layer_call(*args, **kwargs)
#     659     if version_utils.is_v1_layer_or_model(layer):
#     660       conditional_losses = layer.get_losses_for(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/layers/recurrent_v2.py in call(self, inputs, mask, training, initial_state)
#    1250         else:
#    1251           (last_output, outputs, new_h, new_c,
# -> 1252            runtime) = lstm_with_backend_selection(**normal_lstm_kwargs)
#    1253
#    1254       states = [new_h, new_c]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/layers/recurrent_v2.py in lstm_with_backend_selection(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths, zero_output_for_mask)
#    1646     # grappler will kick in during session execution to optimize the graph.
#    1647     last_output, outputs, new_h, new_c, runtime = defun_standard_lstm(**params)
# -> 1648     _function_register(defun_gpu_lstm, **params)
#    1649
#    1650   return last_output, outputs, new_h, new_c, runtime
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/layers/recurrent_v2.py in _function_register(func, *args, **kwargs)
#    1780   concrete_func = func.get_concrete_function(*args, **kwargs)
#    1781   concrete_func.add_to_graph()
# -> 1782   concrete_func.add_gradient_functions_to_graph()
#    1783   return concrete_func
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in add_gradient_functions_to_graph(self, g)
#    2097     self._delayed_rewrite_functions.forward().add_to_graph(g)
#    2098     forward_function, backward_function = (
# -> 2099         self._delayed_rewrite_functions.forward_backward())
#    2100     forward_function.add_to_graph(g)
#    2101     backward_function.add_to_graph(g)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in forward_backward(self, num_doutputs)
#     691     if forward_backward is not None:
#     692       return forward_backward
# --> 693     forward, backward = self._construct_forward_backward(num_doutputs)
#     694     self._cached_function_pairs[num_doutputs] = (forward, backward)
#     695     return forward, backward
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _construct_forward_backward(self, num_doutputs)
#     734       backwards_graph = func_graph_module.FuncGraph(
#     735           _backward_name(self._func_graph.name))
# --> 736       func_graph_module.func_graph_from_py_func(
#     737           name=backwards_graph.name,
#     738           python_func=_backprop_function,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     997         _, original_func = tf_decorator.unwrap(python_func)
#     998
# --> 999       func_outputs = python_func(*func_args, **func_kwargs)
#    1000
#    1001       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _backprop_function(*grad_ys)
#     725     def _backprop_function(*grad_ys):
#     726       with ops.device(None):
# --> 727         return gradients_util._GradientsHelper(  # pylint: disable=protected-access
#     728             trainable_outputs,
#     729             self._func_graph.inputs,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/gradients_util.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     679                 # If grad_fn was found, do not use SymbolicGradient even for
#     680                 # functions.
# --> 681                 in_grads = _MaybeCompile(grad_scope, op, func_call,
#     682                                          lambda: grad_fn(op, *out_grads))
#     683               else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/gradients_util.py in _MaybeCompile(scope, op, func, grad_fn)
#     336
#     337   if not xla_compile:
# --> 338     return grad_fn()  # Exit early
#     339
#     340   # If the gradients are supposed to be compiled separately, we give them a
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/gradients_util.py in <lambda>()
#     680                 # functions.
#     681                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 682                                          lambda: grad_fn(op, *out_grads))
#     683               else:
#     684                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/cudnn_rnn_grad.py in _cudnn_rnn_backward(op, *grads)
#      28     raise ValueError(
#      29         "To use CudnnRNN in gradients, is_training must be set to True.")
# ---> 30   return gen_cudnn_rnn_ops.cudnn_rnn_backprop(
#      31       input=op.inputs[0],
#      32       input_h=op.inputs[1],
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/gen_cudnn_rnn_ops.py in cudnn_rnn_backprop(input, input_h, input_c, params, output, output_h, output_c, output_backprop, output_h_backprop, output_c_backprop, reserve_space, rnn_mode, input_mode, direction, dropout, seed, seed2, name)
#     305     seed2 = 0
#     306   seed2 = _execute.make_int(seed2, "seed2")
# --> 307   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#     308         "CudnnRNNBackprop", input=input, input_h=input_h, input_c=input_c,
#     309                             params=params, output=output, output_h=output_h,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     746       # Add Op to graph
#     747       # pylint: disable=protected-access
# --> 748       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     749                                  name=scope, input_types=input_types,
#     750                                  attrs=attr_protos, op_def=op_def)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     595       if ctxt is not None and hasattr(ctxt, "AddValue"):
#     596         inp = ctxt.AddValue(inp)
# --> 597       inp = self.capture(inp)
#     598       captured_inputs.append(inp)
#     599     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in capture(self, tensor, name, shape)
#     647               % (tensor, tensor.graph, self))
#     648         inner_graph = inner_graph.outer_graph
# --> 649       return self._capture_helper(tensor, name)
#     650     return tensor
#     651
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in _capture_helper(self, tensor, name, shape)
#     653     capture = self._captures.get(id(tensor))
#     654     if capture is None:
# --> 655       placeholder = _create_substitute_placeholder(
#     656           tensor, name=name, dtype=tensor.dtype, shape=shape)
#     657       # Record the composite device as an attribute to the placeholder.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in _create_substitute_placeholder(value, name, dtype, shape)
#    1141     shape = value.shape
#    1142   with ops.control_dependencies(None):
# -> 1143     placeholder = graph_placeholder(
#    1144         dtype=dtype or value.dtype, shape=shape, name=name)
#    1145   custom_gradient.copy_handle_data(value, placeholder)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/graph_only_ops.py in graph_placeholder(dtype, shape, name)
#      36   g = ops.get_default_graph()
#      37   attrs = {"dtype": dtype_value, "shape": shape}
# ---> 38   op = g._create_op_internal(  # pylint: disable=protected-access
#      39       "Placeholder", [], [dtype], input_types=[],
#      40       attrs=attrs, name=name)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     597       inp = self.capture(inp)
#     598       captured_inputs.append(inp)
# --> 599     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     600         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     601         compute_device)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3564           original_op=self._default_original_op,
#    3565           op_def=op_def)
# -> 3566       self._create_op_helper(ret, compute_device=compute_device)
#    3567     return ret
#    3568
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _create_op_helper(self, op, compute_device)
#    3639
#    3640     if compute_device:
# -> 3641       self._apply_device_functions(op)
#    3642
#    3643     # Snapshot the colocation stack metadata before we might generate error
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _apply_device_functions(self, op)
#    4540     # pylint: disable=protected-access
#    4541     prior_device_string = None
# -> 4542     for device_spec in self._device_function_stack.peek_objs():
#    4543       if device_spec.is_null_merge:
#    4544         continue
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/traceable_stack.py in <genexpr>(.0)
#     113   def peek_objs(self):
#     114     """Return iterator over stored objects ordered newest to oldest."""
# --> 115     return (t_obj.obj for t_obj in reversed(self._stack))
#     116
#     117   def peek_traceable_objs(self):
#
# KeyboardInterrupt:

# %%
model_config_train('multi_clf',5,2000,'softmax','./KMTrainingSet/multi/mul_dataset_simulink.csv')
# Out:
# processing dataset
# 11
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100)               42800
# _________________________________________________________________
# dense_1 (Dense)              (None, 11)                1111
# =================================================================
# Total params: 43,911
# Trainable params: 43,911
# Non-trainable params: 0
# _________________________________________________________________
# None
# saving as: multi_clf.pkl
# Epoch 1/5
# 92/92 [==============================] - 3s 16ms/step - loss: 2.1874 - accuracy: 0.4302 - val_loss: 1.4139 - val_accuracy: 0.7914
#
# Epoch 00001: val_loss improved from inf to 1.41387, saving model to multi_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# Epoch 2/5
# 92/92 [==============================] - 1s 12ms/step - loss: 1.1811 - accuracy: 0.8418 - val_loss: 0.6812 - val_accuracy: 0.8731
#
# Epoch 00002: val_loss improved from 1.41387 to 0.68122, saving model to multi_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# Epoch 3/5
# 92/92 [==============================] - 1s 12ms/step - loss: 0.5890 - accuracy: 0.8750 - val_loss: 0.3946 - val_accuracy: 0.8749
#
# Epoch 00003: val_loss improved from 0.68122 to 0.39464, saving model to multi_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# Epoch 4/5
# 92/92 [==============================] - 1s 11ms/step - loss: 0.3612 - accuracy: 0.8793 - val_loss: 0.2930 - val_accuracy: 0.8836
#
# Epoch 00004: val_loss improved from 0.39464 to 0.29303, saving model to multi_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# Epoch 5/5
# 92/92 [==============================] - 1s 12ms/step - loss: 0.2810 - accuracy: 0.8850 - val_loss: 0.2538 - val_accuracy: 0.8849
#
# Epoch 00005: val_loss improved from 0.29303 to 0.25385, saving model to multi_clf.pkl
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# INFO:tensorflow:Assets written to: multi_clf.pkl/assets
# Model has training accuracy of 88.59%

# %%
binary_labels_list = ['NML','FAULT']
binary_model = load_model('binary_clf.pkl')

# %%
multi_labels_list = ['AB', 'AC', 'BC', 'ABC', 'AG', 'BG', 'ABG', 'CG', 'ACG', 'BCG', 'ABCG']
multi_model = load_model('multi_clf.pkl')

# %%
temp = tester(binary_model,pd.read_csv('ml_test.csv'))

# %%
Counter(temp['label'])
# Out:
# Counter({1: 20000})

# %%
temp = tester(binary_model,pd.read_csv('ml_test.csv'))
plotter(temp,binary_labels_list,2)
temp = tester(multi_model,temp[temp.label!=0])
high = plotter(temp,multi_labels_list,2)
print(high)

# %%
# current directory
path = "./KMTrainingSet/"

# list of file of the given path is assigned to the variable 
file_list = [each for each in list(os.walk(path))[0][-1] if ".csv" in each]

# %%
files_failing_the_test = []
files_passing_the_test = []

for each in file_list:
    print("\n.\n.\n",each)  
    temp = tester(binary_model,pd.read_csv('./KMTrainingSet/'+each))
    plotter(temp,binary_labels_list,2)
    temp = tester(multi_model,temp[temp.label!=0])
    high = plotter(temp,multi_labels_list,2)
    if high == ''.join([i for i in each.split(".")[0] if not i.isdigit()]):
        files_passing_the_test.append(each)
    else:
        files_failing_the_test.append(each)
# Out:
# .
# .
#  5ABCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  10ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.97%
# 1        BCG      0.04%
# .
# .
#  3BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     80.15%
# 1        BCG     19.85%
# .
# .
#  3CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  1BCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     90.45%
# 1        BCG      9.54%
# .
# .
#  7BG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     98.61%
# 1        BCG       1.4%
# .
# .
#  5BG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     98.71%
# 1        BCG      1.29%
# .
# .
#  9ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.99%
# 1        BCG      0.01%
# .
# .
#  1BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.79%
# 1        BCG      0.21%
# .
# .
#  1CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  5ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  9AG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     87.33%
# 1        ABG     12.68%
# .
# .
#  7ABC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  7ACG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  7ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.97%
# 1        BCG      0.03%
# .
# .
#  9AC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.99%
# 1        BCG      0.01%
# .
# .
#  1BG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     98.59%
# 1        BCG      1.41%
# .
# .
#  5ABC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  5ACG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  9AB.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  9ACG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  9ABC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  5BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC      99.3%
# 1        BCG       0.7%
# .
# .
#  5CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  4ABCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  7BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     83.91%
# 1        BCG     16.09%
# .
# .
#  7CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  10ACG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  3BG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     98.72%
# 1        BCG      1.28%
# .
# .
#  10ABC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  3BCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.85%
# 1        BCG      0.15%
# .
# .
#  4BG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.45%
# 1        BCG      0.55%
# .
# .
#  1ABC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  1ACG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.95%
# 1        ABG      0.04%
# 2        BCG      0.01%
# .
# .
#  8AG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     67.25%
# 1        ABG     32.74%
# .
# .
#  3ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.99%
# 1        BCG      0.01%
# .
# .
#  10AC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  7BCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     85.75%
# 1        BCG     14.24%
# .
# .
#  6ABCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# 1        ABG      0.01%
# .
# .
#  6BG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.92%
# 1        BCG      0.09%
# .
# .
#  10AB.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  2BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     97.25%
# 1        BCG      2.75%
# .
# .
#  2CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  5BCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.75%
# 1        BCG      0.26%
# .
# .
#  2BG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     98.61%
# 1        BCG       1.4%
# .
# .
#  6BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     86.69%
# 1        BCG      13.3%
# .
# .
#  6CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  7ABCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  9BCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.81%
# 1        BCG      0.19%
# .
# .
#  10AG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     65.81%
# 1        ABG     34.19%
# .
# .
#  3ABC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# 1        ABG      0.01%
# .
# .
#  3ACG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  8AC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  4BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     74.75%
# 1        BCG     25.25%
# .
# .
#  4CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  1ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.98%
# 1        BCG      0.01%
# .
# .
#  8AB.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  10BCG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        BCG      57.4%
# 1        ABC      42.6%
# .
# .
#  8CG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  8BC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     81.84%
# 1        BCG     18.16%
# .
# .
#  4AB.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  6ACG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# 1        BCG      0.01%
# .
# .
#  6ABC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# 1        BCG      0.01%
# .
# .
#  8ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.98%
# 1        BCG      0.02%
# .
# .
#  4AC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.99%
# 1        BCG      0.01%
# .
# .
#  4ABG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     100.0%
# .
# .
#  2AG.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC      98.7%
# 1        ABG       1.3%
# .
# .
#  6AC.csv
#   Fault type Percentage
# 0      FAULT     100.0%
#   Fault type Percentage
# 0        ABC     99.99%
# 1        BCG      0.01%
# .
# .
#  6AB.csv
#   Fault type Percentage
# 0      FAULT     100.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-937a790914d2> in <module>
#       5     print("\n.\n.\n",each)
#       6     temp = tester(binary_model,pd.read_csv('./KMTrainingSet/'+each))
# ----> 7     plotter(temp,binary_labels_list,2)
#       8     temp = tester(multi_model,temp[temp.label!=0])
#       9     high = plotter(temp,multi_labels_list,2)
#
# <ipython-input-6-45ebbc669c04> in plotter(plot_data, unique_labels, n_plots)
#      26     data['label'] = [unique_labels[i] for i in predicted_labels]
#      27
# ---> 28     fig, ax = plt.subplots(n_plots,figsize=(15,4*n_plots))
#      29
#      30     for j in range(n_plots):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1286     """
#    1287     fig = figure(**fig_kw)
# -> 1288     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1289                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1290                        gridspec_kw=gridspec_kw)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1520         if gridspec_kw is None:
#    1521             gridspec_kw = {}
# -> 1522         return (self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#    1523                 .subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#    1524                           subplot_kw=subplot_kw))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/gridspec.py in subplots(self, sharex, sharey, squeeze, subplot_kw)
#     334                 subplot_kw["sharex"] = shared_with[sharex]
#     335                 subplot_kw["sharey"] = shared_with[sharey]
# --> 336                 axarr[row, col] = figure.add_subplot(
#     337                     self[row, col], **subplot_kw)
#     338
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
# ---> 42         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      43         # add a layout box to this, for both the full axis, and the poss
#      44         # of the axis.  We need both because the axes may become smaller
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     509
#     510         self._rasterization_zorder = None
# --> 511         self.cla()
#     512
#     513         # funcs used to format x and y - fall back on major formatters
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in cla(self)
#    1159         self.set_axis_on()
#    1160
# -> 1161         self.xaxis.set_clip_path(self.patch)
#    1162         self.yaxis.set_clip_path(self.patch)
#    1163
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in set_clip_path(self, clippath, transform)
#     899     def set_clip_path(self, clippath, transform=None):
#     900         martist.Artist.set_clip_path(self, clippath, transform)
# --> 901         for child in self.majorTicks + self.minorTicks:
#     902             child.set_clip_path(clippath, transform)
#     903         self.stale = True
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     621             else:
#     622                 instance.minorTicks = []
# --> 623                 tick = instance._get_tick(major=False)
#     624                 instance.minorTicks.append(tick)
#     625                 return instance.minorTicks
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2011         else:
#    2012             tick_kw = self._minor_tick_kw
# -> 2013         return XTick(self.axes, 0, major=major, **tick_kw)
#    2014
#    2015     def set_label_position(self, position):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     433         # the y loc is 3 points below the min of y axis
#     434         trans, va, ha = self._get_text1_transform()
# --> 435         self.label1.set(
#     436             x=0, y=0,
#     437             verticalalignment=va, horizontalalignment=ha, transform=trans,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1111         if move_color_to_start:
#    1112             kwargs = {"color": kwargs.pop("color"), **kwargs}
# -> 1113         return self.update(kwargs)
#    1114
#    1115     def findobj(self, match=None, include_self=True):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/text.py in update(self, kwargs)
#     175         # Update bbox last, as it depends on font properties.
#     176         bbox = kwargs.pop("bbox", sentinel)
# --> 177         super().update(kwargs)
#     178         if bbox is not sentinel:
#     179             self.set_bbox(bbox)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#     996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
# --> 998                     ret.append(func(v))
#     999         if ret:
#    1000             self.pchanged()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/text.py in set_x(self, x)
#    1107         """
#    1108         self._x = x
# -> 1109         self.stale = True
#    1110
#    1111     def set_y(self, y):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in stale(self, val)
#     218         # draw stack and is not expected to be drawn as part of the normal
#     219         # draw loop (when not saving) so do not propagate this change
# --> 220         if self.get_animated():
#     221             return
#     222
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in get_animated(self)
#     796     def get_animated(self):
#     797         """Return whether the artist is animated."""
# --> 798         return self._animated
#     799
#     800     def get_in_layout(self):
#
# KeyboardInterrupt:

# %%
print(files_passing_the_test,"....\n\n....",files_failing_the_test)

# %%
names = [''.join([i for i in each.split(".")[0] if not i.isdigit()]) for each in files_passing_the_test]

# %%
Counter(names)

# %%
temp = tester(binary_model,pd.read_csv('ml_test.csv'))
plotter(temp,binary_labels_list,2)
temp = tester(multi_model,temp[temp.label!=0])
high = plotter(temp,multi_labels_list,2)
print(high)

# %%
files_failing_the_test = []
files_passing_the_test = []
for i in range(1,10):
    print("___________________________________________________________________")
    temp = tester(binary_model,pd.read_csv('./KMTrainingSet/'+str(i)+'ABC.csv'))
    plotter(temp,binary_labels_list,2)
    temp = tester(multi_model,temp[temp.label!=0])
    high = plotter(temp,multi_labels_list,2)
    if high == ''.join([i for i in each.split(".")[0] if not i.isdigit()]):
        checker.append(str(i)+'ABC.csv')
    else:
        checker.append('incorrect')
    print("----------------------------------------------------------------")

# %%
files_failing_model = [str(i)+'ABC.csv' for i in range(len(checker)) if checker[i]=='incorrect']

names = [''.join([i for i in each.split(".")[0] if not i.isdigit()]) for each in files_failing_model]

# %%
Counter(names)

# %%
data = pd.read_csv('./KMTrainingSet/1AG.csv')

# %%
round(data['3V'])

# %%
dat = Counter((round(data['3V'])/10))
matrics = sorted(zip([each for each in Counter(dat).keys()],Counter(dat).values() ), key=lambda x: x[0])

# %%
data = pd.read_csv('KMTrainingset/2ABG.csv')

# %%
features = data[data.columns[:-1]].values.tolist()
#true_labels = data['label'].values.tolist()

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
scaled_features

# %%
kmeans = KMeans(
    init="random",
    n_clusters=2,
    n_init=10,
    max_iter=500,
    random_state=42
)

# %%
kmeans.fit(scaled_features)

# %%
kmeans.cluster_centers_

# %%
labels = kmeans.fit_predict(features)

# %%
#data['label']=labels
data.head()

# %%
dic = Counter(labels)

# %%
dic

# %%
if dic[1]>dic[0]:
    print("1 = 0 , 0 =1")
    data['label']=[1 if i == 0 else 0 for i in labels]
else:
    print(True)

# %%
dic = Counter(data['label'])

# %%
data

# %%
n_plots = 6
fig, ax = plt.subplots(n_plots,figsize=(15,4*n_plots))
unique_labels = ['NML','Fault']
cols = data.columns[:-1]

for j in range(6):

    
    legend_list = []
    for i in list(set(data.label)):
        
        plo = data[data.label == i]
        temp = ax[j].scatter(plo.index,plo[cols[j]],marker='+',s=40)  


        legend_list.append(temp)

    ax[j].legend(legend_list,unique_labels,scatterpoints=3,ncol=1,fontsize=15)

fig.tight_layout()
plt.show()

# %%
org = [0,1,0,1,1,1,0,0,1,0,1]
[1 if i == 0 else 0 for i in org]

# %%
for x,y in zip(org,[1 if i == 0 else 0 for i in org]):
    print(x+y)
